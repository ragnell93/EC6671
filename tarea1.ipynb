# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil
import posixpath

import wfdb

# %%
record = wfdb.rdrecord('04100001', pn_dir='mimicdb/041', sampfrom=100, sampto=1000, channels=[0])
wfdb.plot_wfdb(record=record, title='MIMIC DB portion of sample 041') 
annotation = wfdb.rdann('04100001', 'txt', sampfrom=100, sampto=1000, pn_dir='mimicdb/041')
display(annotation.__dict__)
# Out:
# {'record_name': '04100001',
#  'extension': 'txt',
#  'sample': array([659]),
#  'symbol': ['~'],
#  'subtype': array([0]),
#  'chan': array([0]),
#  'num': array([0]),
#  'aux_note': [''],
#  'fs': 125,
#  'label_store': None,
#  'description': None,
#  'custom_labels': None,
#  'contained_labels': None,
#  'ann_len': 1}

# %%
record2 = wfdb.rdrecord('03900001', pn_dir='mimicdb/039', sampfrom=100, sampto=1000, channels=[0])
wfdb.plot_wfdb(record=record2, title='MIMIC DB portion of sample 039') 
annotation2 = wfdb.rdann('03900001', 'txt', sampfrom=100, sampto=1000, pn_dir='mimicdb/039')
display(annotation2.__dict__)
# Out:
# {'record_name': '03900001',
#  'extension': 'txt',
#  'sample': array([652, 958]),
#  'symbol': ['~', '~'],
#  'subtype': array([0, 0]),
#  'chan': array([0, 0]),
#  'num': array([0, 0]),
#  'aux_note': ['', ''],
#  'fs': 125,
#  'label_store': None,
#  'description': None,
#  'custom_labels': None,
#  'contained_labels': None,
#  'ann_len': 2}
